# %% [markdown]
# <a href="https://colab.research.google.com/github/mggg/Computational-Tools-Workshop-2026/blob/main/votekit_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install votekit==0.3.2
